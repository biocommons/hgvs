# %% [markdown]
# # hgvs Documention: Examples
#
# This notebook is being drafted to run and review the current state presented in the hgvs documentation "Creating a SequenceVariant from scratch" section (https://hgvs.readthedocs.io/en/stable/examples/creating-a-variant.html#overview).
#
# ## Purpose
# User stories will be provided as users progress through the current state of the aformentioned documentation.  This will provide reasonable framework for assessing functional and non-functional requirements of the hgvs documentation page.
#
# ### User Credentials
# This section is for people to provide their background
#
#     Occupation:             Molecular Biologist
#
#     Experience in Biology:  8 years
#
#     Experience in Python:   ~1 year

# %% [markdown]
# ## 0. Overview
# A SequenceVariant consists of an accession (a string), a sequence type (a string), and a PosEdit, like this:
#
# var = hgvs.variant.SequenceVariant(ac=’NM_01234.5’, type=’c’, posedit=…)
#
# Unsurprisingly, a PosEdit consists of separate position and Edit objects. A position is generally an Interval, which in turn is comprised of SimplePosition or BaseOffsetPosition objects. An edit is a subclass of Edit, which includes classes like NARefAlt for substitutions, deletions, and insertions) and Dup (for duplications).
#
# Importantly, each of the objects we’re building has a rule in the parser, which means that you have the tools to serialize and deserialize (parse) each of the components that we’re about to construct.
#
# #### User Story:
# I went to this page to learn how to propose variants.  I would like to see an overview that explicity explains what is covered and the rigor of each step.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### User Story:
# 1) Review of this section makes me think that I am creating a variant that can be used on any segment of r. and c. sequeces.
# 2) I am curious to know more about the use of location

# %%
# User execution of steps
import hgvs.location
import hgvs.posedit
